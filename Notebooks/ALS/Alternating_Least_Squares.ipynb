# %% [markdown]
# <a href="https://colab.research.google.com/github/look4pritam/NetflixPrize/blob/master/Notebooks/ALS/Alternating_Least_Squares.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Netflix Prize

# %% [markdown]
# ## Install Python packages.

# %%
# !pip install numpy pandas scipy tqdm
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (1.16.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# ## Set the project root directory.

# %%
import os

root_dir = '/content/'
os.chdir(root_dir)

# !ls -al
# Out:
# total 20
# drwxr-xr-x 1 root root 4096 Apr 20 05:43 .
# drwxr-xr-x 1 root root 4096 Apr 20 04:31 ..
# drwxr-xr-x 4 root root 4096 Apr 16 13:28 .config
# -rw-r--r-- 1 root root   67 Apr 20 05:43 kaggle.json
# drwxr-xr-x 1 root root 4096 Apr 16 13:28 sample_data

# %% [markdown]
# ## Download the Netflix Prize dataset from Kaggle.

# %% [markdown]
# ### Set the Kaggle API key.

# %% [markdown]
# ### Generate and upload 'kaggle.json' file.

# %%
os.environ['KAGGLE_CONFIG_DIR'] = root_dir
# !chmod 600 /content/kaggle.json

# %% [markdown]
# ### Download the Netflix Prize dataset.

# %%
# !kaggle datasets download netflix-inc/netflix-prize-data
# !ls -al
# Out:
# Dataset URL: https://www.kaggle.com/datasets/netflix-inc/netflix-prize-data
# License(s): other
# Downloading netflix-prize-data.zip to /content
# 100% 683M/683M [00:06<00:00, 110MB/s]
#
# total 699436
# drwxr-xr-x 1 root root      4096 Apr 20 05:43 .
# drwxr-xr-x 1 root root      4096 Apr 20 04:31 ..
# drwxr-xr-x 4 root root      4096 Apr 16 13:28 .config
# -rw------- 1 root root        67 Apr 20 05:43 kaggle.json
# -rw-r--r-- 1 root root 716193814 Nov 13  2019 netflix-prize-data.zip
# drwxr-xr-x 1 root root      4096 Apr 16 13:28 sample_data

# %%
import os
import zipfile

# %% [markdown]
# ### Extract the Netflix Prize dataset.

# %%
zip_path = "netflix-prize-data.zip"
dataset_path = "netflix_dataset"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(dataset_path)

print("Extracted Netflix Prize dataset from:", os.listdir(dataset_path))
# Out:
# Extracted Netflix Prize dataset from: ['probe.txt', 'combined_data_3.txt', 'README', 'combined_data_2.txt', 'movie_titles.csv', 'combined_data_4.txt', 'qualifying.txt', 'combined_data_1.txt']

# %% [markdown]
# ## Load the Netflix Prize dataset.

# %% [markdown]
# ### Import Python packages.

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm

# %%
def load_netflix_data(filepath, max_rows=500000):

    user_ids = []
    movie_ids = []
    ratings = []

    movie_id = None
    count = 0

    with open(filepath, "r") as f:

        for line in f:

            if ":" in line:
                movie_id = int(line.replace(":", "").strip())

            else:
                user, rating, _ = line.split(",")

                user_ids.append(int(user))
                movie_ids.append(movie_id)
                ratings.append(float(rating))

                count += 1

                if count >= max_rows:
                    break

    df = pd.DataFrame({
        "user": user_ids,
        "movie": movie_ids,
        "rating": ratings
    })

    return df

# %%
file_path = "netflix_dataset/combined_data_1.txt"
df = load_netflix_data(file_path, max_rows=500000)
df.head()
# Out:
#       user  movie  rating
# 0  1488844      1     3.0
# 1   822109      1     5.0
# 2   885013      1     4.0
# 3    30878      1     4.0
# 4   823519      1     3.0

# %%
user_map = {user:index for index,user in enumerate(df.user.unique())}
movie_map = {movie:index for index,movie in enumerate(df.movie.unique())}

df["user_idx"] = df.user.map(user_map)
df["movie_idx"] = df.movie.map(movie_map)

user_count = len(user_map)
movie_count = len(movie_map)

print("Number of users: ", user_count)
print("Number of movies: ", movie_count)
# Out:
# Number of users:  215008
# Number of movies:  148

# %% [markdown]
# ## Compute the sparse matrix in COO format.
#
# ### COO format:
# - Stores only non-zero entries
# - Efficient for large sparse data
#
# ### Components:
# - matrix.row - user indices
# - matrix.col - movie indices
# - matrix.data - ratings

# %%
from scipy.sparse import coo_matrix

# %%
matrix = coo_matrix(
    (df.rating, (df.user_idx, df.movie_idx)),
    shape=(user_count, movie_count)
)

# %% [markdown]
# ## Factorize matrix using Alternating Least Squares (ALS).

# %%
def matrix_factorization(matrix, embedding_size=20, iterations=5, reg=0.1):

    user_count, sample_count = matrix.shape

    U = np.random.normal(scale=1./embedding_size, size=(user_count, embedding_size))
    V = np.random.normal(scale=1./embedding_size, size=(sample_count, embedding_size))

    rows = matrix.row
    cols = matrix.col
    ratings = matrix.data

    for current_iteration in range(iterations):

        print("Iteration: ", current_iteration+1)

        # Update Users
        for u in tqdm(range(user_count)):

            idx = rows == u
            items = cols[idx]
            r = ratings[idx]

            if len(items) == 0:
                continue

            V_i = V[items]

            A = V_i.T @ V_i + reg*np.eye(embedding_size)
            b = V_i.T @ r

            U[u] = np.linalg.solve(A, b)

        # Update Movies
        for i in tqdm(range(sample_count)):

            idx = cols == i
            users = rows[idx]
            r = ratings[idx]

            if len(users) == 0:
                continue

            U_u = U[users]

            A = U_u.T @ U_u + reg*np.eye(embedding_size)
            b = U_u.T @ r

            V[i] = np.linalg.solve(A, b)

    return U, V

# %%
U, V = matrix_factorization(matrix, embedding_size=20, iterations=5)
# Out:
# Iteration:  1
# 100%|██████████| 215008/215008 [02:07<00:00, 1688.81it/s]
# 100%|██████████| 148/148 [00:01<00:00, 83.69it/s]
# Iteration:  2
# 100%|██████████| 215008/215008 [01:52<00:00, 1906.16it/s]
# 100%|██████████| 148/148 [00:00<00:00, 501.01it/s]
# Iteration:  3
# 100%|██████████| 215008/215008 [01:55<00:00, 1853.58it/s]
# 100%|██████████| 148/148 [00:00<00:00, 460.16it/s]
# Iteration:  4
# 100%|██████████| 215008/215008 [01:51<00:00, 1921.30it/s]
# 100%|██████████| 148/148 [00:00<00:00, 379.24it/s]
# Iteration:  5
# 100%|██████████| 215008/215008 [02:09<00:00, 1658.07it/s]
# 100%|██████████| 148/148 [00:00<00:00, 236.49it/s]

# %% [markdown]
# ## Compute the predicted matrix.

# %%
predicted_matrix = U @ V.T

# %% [markdown]
# ## Computer the RMSE metric.

# %%
def compute_rmse(matrix, predicted_matrix):

    rows = matrix.row
    cols = matrix.col
    ground_truth_ratings = matrix.data

    predicted_ratings = predicted_matrix[rows, cols]

    rmse = np.sqrt(np.mean((ground_truth_ratings - predicted_ratings)**2))

    return rmse

# %%
rmse = compute_rmse(matrix, predicted_matrix)
print("RMSE: ", rmse)
# Out:
# RMSE: 0.09647462235292073
